# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# # Online Sales Data

# %% [markdown]
# # Introduction

# %% [raw]
# The online_sales_data.csv dataset contains comprehensive records of online sales transactions, encompassing crucial details such as transaction IDs, product identifiers, descriptions, quantities purchased, unit prices, transaction dates, customer identifiers, and customer locations. The dataset contains 240 rows and 9 columns, each representing a unique Online sale.

# %% [markdown]
# # Questions

# %% [markdown]
# 1. Display the summary information of the DataFrame.
# 2. Display the first 10 rows.
# 3. Check the number of rows and columns in the DataFrame. Select and display the 'UnitPrice' column.
# 4. Select and display the rows where 'Quantity' is greater than 2.
# 5. Select rows where the 'UnitPrice' is greater than $1000.
# 6. Select and display the 'Transaction ID', 'Product Category', and 'Region' columns for transactions where the quantity is more than 3.
# 7. Select and display rows where the 'Date' is before May 1, 2024.
# 8. Sort the DataFrame by 'Quantity' and then by 'UnitPrice' in ascending order
# 9. How many unique products are sold in the dataset?
# 10. What is the total revenue (sum of Unit Price * Quantity) generated from these sales?
# 11. Show the summary statistics (mean, min, max, etc.) for the Quantity column.
# 12. Which product generated the highest revenue? Display the product details.
# 13. How many transactions were made in each Country?
# 14. List the top 2 countries by total revenue.
# 15. Calculate the average unit price for each product.
# 16. Which day had the highest sales revenue? Display the date and the revenue.
# 17. Check if there are any duplicate values in the 'Transaction ID' column.
# 18. Filter the dataset to include only transactions where Quantity is greater than 10.
# 19. Calculate the total revenue for each CustomerID.
# 20. Group the data by 'InvoiceNo' and find the maximum 'UnitPrice' for each invoice.

# %%
data=pd.read_csv('Online Sales Data.csv')
data
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %% [markdown]
# # 1. Display the summary information of the DataFrame.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    240 non-null    int64
#  1   Date              240 non-null    object
#  2   Product Category  240 non-null    object
#  3   Product Name      240 non-null    object
#  4   Units Sold        240 non-null    int64
#  5   Unit Price        240 non-null    float64
#  6   Total Revenue     240 non-null    float64
#  7   Region            240 non-null    object
#  8   Payment Method    240 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 17.0+ KB

# %%
data.size
# Out:
# 2160

# %%
data.shape
# Out:
# (240, 9)

# %%
data.describe()
# Out:
#        Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000

# %%
data.isna()
# Out:
#      Transaction ID   Date  Product Category  Product Name  Units Sold  \
# 0             False  False             False         False       False
# 1             False  False             False         False       False
# 2             False  False             False         False       False
# 3             False  False             False         False       False
# 4             False  False             False         False       False
# ..              ...    ...               ...           ...         ...
# 235           False  False             False         False       False
# 236           False  False             False         False       False
# 237           False  False             False         False       False
# 238           False  False             False         False       False
# 239           False  False             False         False       False
#
#      Unit Price  Total Revenue  Region  Payment Method
# 0         False          False   False           False
# ...

# %% [markdown]
# * the data contains 240 rows and 9 columns with a total of 2160 entries, there are no null values present in the data. the data types included in the data are object, int and float

# %%
def convert (date):
    return pd.to_datetime(date)
    
data['Date']=data['Date'].apply(convert)
data
# Out:
#      Transaction ID       Date Product Category  \
# 0             10001 2024-01-01      Electronics
# 1             10002 2024-01-02  Home Appliances
# 2             10003 2024-01-03         Clothing
# 3             10004 2024-01-04            Books
# 4             10005 2024-01-05  Beauty Products
# ..              ...        ...              ...
# 235           10236 2024-08-23  Home Appliances
# 236           10237 2024-08-24         Clothing
# 237           10238 2024-08-25            Books
# 238           10239 2024-08-26  Beauty Products
# 239           10240 2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %% [markdown]
# * the data type of date is converted to datetime

# %% [markdown]
# # 2. Display the first 10 rows.

# %%
data.head(10)
# Out:
#    Transaction ID       Date Product Category                 Product Name  \
# 0           10001 2024-01-01      Electronics                iPhone 14 Pro
# 1           10002 2024-01-02  Home Appliances             Dyson V11 Vacuum
# 2           10003 2024-01-03         Clothing             Levi's 501 Jeans
# 3           10004 2024-01-04            Books            The Da Vinci Code
# 4           10005 2024-01-05  Beauty Products      Neutrogena Skincare Set
# 5           10006 2024-01-06           Sports  Wilson Evolution Basketball
# 6           10007 2024-01-07      Electronics          MacBook Pro 16-inch
# 7           10008 2024-01-08  Home Appliances         Blueair Classic 480i
# 8           10009 2024-01-09         Clothing             Nike Air Force 1
# 9           10010 2024-01-10            Books        Dune by Frank Herbert
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# ...

# %% [markdown]
# # 3. Check the number of rows and columns in the DataFrame. Select and display the 'UnitPrice' column.

# %%
data.shape
# Out:
# (240, 9)

# %%
data.shape[0]
# Out:
# 240

# %% [markdown]
# * number of rows

# %%
data.shape[1]
# Out:
# 9

# %% [markdown]
# * no of columns

# %%
data['Unit Price'].to_frame()
# Out:
#      Unit Price
# 0        999.99
# 1        499.99
# 2         69.99
# 3         15.99
# 4         89.99
# ..          ...
# 235      159.99
# 236       90.00
# 237       10.99
# 238       55.00
# 239       29.99
#
# [240 rows x 1 columns]

# %% [markdown]
# # 4. Select and display the rows where 'Quantity' is greater than 2.

# %%
data[data['Units Sold']>2]
# Out:
#      Transaction ID       Date Product Category  \
# 2             10003 2024-01-03         Clothing
# 3             10004 2024-01-04            Books
# 5             10006 2024-01-06           Sports
# 8             10009 2024-01-09         Clothing
# 11            10012 2024-01-12           Sports
# ..              ...        ...              ...
# 225           10226 2024-08-13            Books
# 230           10231 2024-08-18         Clothing
# 233           10234 2024-08-21           Sports
# 236           10237 2024-08-24         Clothing
# 237           10238 2024-08-25            Books
#
#                                 Product Name  Units Sold  Unit Price  \
# 2                           Levi's 501 Jeans           3       69.99
# 3                          The Da Vinci Code           4       15.99
# 5                Wilson Evolution Basketball           5       29.99
# 8                           Nike Air Force 1           6       89.99
# ...

# %% [markdown]
# * rows with the Units sold more than 2 are displayed

# %% [markdown]
# # 5. Select rows where the 'UnitPrice' is greater than $1000.

# %%
data[data['Unit Price']>1000]
# Out:
#      Transaction ID       Date Product Category  \
# 6             10007 2024-01-07      Electronics
# 35            10036 2024-02-05           Sports
# 66            10067 2024-03-07      Electronics
# 72            10073 2024-03-13      Electronics
# 85            10086 2024-03-26  Home Appliances
# 102           10103 2024-04-12      Electronics
# 132           10133 2024-05-12      Electronics
# 138           10139 2024-05-18      Electronics
# 162           10163 2024-06-11      Electronics
# 216           10217 2024-08-04      Electronics
#
#                           Product Name  Units Sold  Unit Price  Total Revenue  \
# 6                  MacBook Pro 16-inch           1     2499.99        2499.99
# 35                        Peloton Bike           1     1895.00        1895.00
# 66                  Samsung QLED 4K TV           1     1199.99        1199.99
# 72              HP Spectre x360 Laptop           1     1599.99        1599.99
# ...

# %% [markdown]
# * rows with the UnitPrice more than 1000 is displayed

# %% [markdown]
# # 6. Select and display the 'Transaction ID', 'Product Category', and 'Region' columns for transactions where the quantity is more than 3.

# %%
df=data[['Transaction ID','Product Category','Region','Units Sold']]
df[df['Units Sold']>3]
# Out:
#      Transaction ID Product Category         Region  Units Sold
# 3             10004            Books  North America           4
# 5             10006           Sports           Asia           5
# 8             10009         Clothing           Asia           6
# 17            10018           Sports           Asia           4
# 32            10033         Clothing           Asia           5
# 33            10034            Books  North America           4
# 38            10039         Clothing           Asia           4
# 45            10046            Books  North America           4
# 47            10048           Sports           Asia           6
# 53            10054           Sports           Asia           5
# 54            10055      Electronics  North America           4
# 56            10057         Clothing           Asia           5
# 62            10063         Clothing           Asia          10
# 63            10064            Books  North America           4
# ...

# %% [markdown]
# * the transactionn id, product category and region columns for those with units sold more than 3 are selected and displayed

# %% [markdown]
# # 7. Select and display rows where the 'Date' is before May 1, 2024.

# %%
data[data['Date']<'2024-05-01']
# Out:
#      Transaction ID       Date Product Category  \
# 0             10001 2024-01-01      Electronics
# 1             10002 2024-01-02  Home Appliances
# 2             10003 2024-01-03         Clothing
# 3             10004 2024-01-04            Books
# 4             10005 2024-01-05  Beauty Products
# ..              ...        ...              ...
# 116           10117 2024-04-26         Clothing
# 117           10118 2024-04-27            Books
# 118           10119 2024-04-28  Beauty Products
# 119           10120 2024-04-29           Sports
# 120           10121 2024-04-30      Electronics
#
#                          Product Name  Units Sold  Unit Price  Total Revenue  \
# 0                       iPhone 14 Pro           2      999.99        1999.98
# 1                    Dyson V11 Vacuum           1      499.99         499.99
# 2                    Levi's 501 Jeans           3       69.99         209.97
# ...

# %% [markdown]
# * the rows given here are the transactions that are done on or before may 1 2024

# %% [markdown]
# # 8. Sort the DataFrame by 'Quantity' and then by 'UnitPrice' in ascending order

# %%
data.sort_values(by=['Units Sold','Unit Price'])
# Out:
#      Transaction ID       Date Product Category  \
# 106           10107 2024-04-16  Beauty Products
# 226           10227 2024-08-14  Beauty Products
# 136           10137 2024-05-16  Beauty Products
# 112           10113 2024-04-22  Beauty Products
# 166           10167 2024-06-15  Beauty Products
# ..              ...        ...              ...
# 98            10099 2024-04-08         Clothing
# 83            10084 2024-03-24           Sports
# 47            10048 2024-02-17           Sports
# 8             10009 2024-01-09         Clothing
# 62            10063 2024-03-03         Clothing
#
#                                     Product Name  Units Sold  Unit Price  \
# 106               The Ordinary Niacinamide Serum           1        6.50
# 226     The Ordinary Caffeine Solution 5% + EGCG           1        6.70
# 136           The Ordinary Hyaluronic Acid Serum           1        6.80
# 112  Biore UV Aqua Rich Watery Essence Sunscreen           1       15.00
# ...

# %% [markdown]
# # 9. How many unique products are sold in the dataset?

# %%
data['Product Category'].unique()
# Out:
# array(['Electronics', 'Home Appliances', 'Clothing', 'Books',
#        'Beauty Products', 'Sports'], dtype=object)

# %% [markdown]
# * the unique products given sold in the dataset are 'Electronics', 'Home Appliances', 'Clothing', 'Books',
#        'Beauty Products', 'Sports'

# %% [markdown]
# # 10. What is the total revenue (sum of Unit Price * Quantity) generated from these sales?

# %%
def tot_rev(data):
    return data['Units Sold']*data['Unit Price']
data['total revenue']=data.apply(tot_rev,axis=1)
data['total revenue'].to_frame()
# Out:
#      total revenue
# 0          1999.98
# 1           499.99
# 2           209.97
# 3            63.96
# 4            89.99
# ..             ...
# 235         159.99
# 236         270.00
# 237          32.97
# 238          55.00
# 239          59.98
#
# [240 rows x 1 columns]

# %% [markdown]
# * a new columns is created as total revenue which contains the product of Unit price and units sold

# %% [markdown]
# # 11. Show the summary statistics (mean, min, max, etc.) for the Quantity column.

# %%
data['Units Sold'].describe()
# Out:
# count    240.000000
# mean       2.158333
# std        1.322454
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max       10.000000
# Name: Units Sold, dtype: float64

# %% [markdown]
# * mean, min, max and other statistical summary are shown for the Units Sold column

# %% [markdown]
# # 12. Which product generated the highest revenue? Display the product details.

# %%
data.sort_values(by='Total Revenue',ascending= False)
# Out:
#      Transaction ID       Date Product Category  \
# 102           10103 2024-04-12      Electronics
# 85            10086 2024-03-26  Home Appliances
# 6             10007 2024-01-07      Electronics
# 216           10217 2024-08-04      Electronics
# 0             10001 2024-01-01      Electronics
# ..              ...        ...              ...
# 166           10167 2024-06-15  Beauty Products
# 112           10113 2024-04-22  Beauty Products
# 136           10137 2024-05-16  Beauty Products
# 226           10227 2024-08-14  Beauty Products
# 106           10107 2024-04-16  Beauty Products
#
#                                     Product Name  Units Sold  Unit Price  \
# 102                          Canon EOS R5 Camera           1     3899.99
# 85                                    LG OLED TV           2     1299.99
# 6                            MacBook Pro 16-inch           1     2499.99
# 216                    Apple MacBook Pro 16-inch           1     2399.00
# ...

# %%
data['Total Revenue'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 240 entries, 0 to 239
# Series name: Total Revenue
# Non-Null Count  Dtype
# --------------  -----
# 240 non-null    float64
# dtypes: float64(1)
# memory usage: 2.0 KB

# %% [markdown]
# * the highest revenue generating product is Canon EOS R5 Camera in Electronics category, the dtype of the column is float which take 2.0 kb of memory

# %% [markdown]
# # 13. How many transactions were made in each Country?

# %%
data['Region'].value_counts()
# Out:
# Region
# North America    80
# Europe           80
# Asia             80
# Name: count, dtype: int64

# %% [markdown]
# * this shows the distribution of sales in each country

# %% [markdown]
# # 14. List the top 2 countries by total revenue.

# %%
a=data.sort_values(by='Total Revenue',ascending= False)
a[['Region','Total Revenue']].head(2)
# Out:
#             Region  Total Revenue
# 102  North America        3899.99
# 85          Europe        2599.98

# %% [markdown]
# * the 2 countries with highest total revenue are displayed

# %% [markdown]
# # 15. Calculate the average unit price for each product.

# %%
data.groupby(['Product Name'])['Unit Price'].mean().to_frame()
# Out:
#                                                     Unit Price
# Product Name
# 1984 by George Orwell                                    19.99
# Adidas 3-Stripes Shorts                                  29.99
# Adidas Essential Track Pants                             44.99
# Adidas FIFA World Cup Football                           29.99
# Adidas Originals Superstar Sneakers                      79.99
# ...                                                        ...
# Yeti Tundra Haul Portable Wheeled Cooler                399.99
# Youth to the People Superfood Antioxidant Cleanser       36.00
# Zara Summer Dress                                        59.99
# iPhone 14 Pro                                           999.99
# iRobot Braava Jet M6                                    449.99
#
# [232 rows x 1 columns]

# %% [markdown]
# * the average price of each product is displayed

# %% [markdown]
# # 16. Which day had the highest sales revenue? Display the date and the revenue.

# %%
a=data.sort_values(by='Total Revenue', ascending= False)
a[['Date','Total Revenue']]
# Out:
#           Date  Total Revenue
# 102 2024-04-12        3899.99
# 85  2024-03-26        2599.98
# 6   2024-01-07        2499.99
# 216 2024-08-04        2399.00
# 0   2024-01-01        1999.98
# ..         ...            ...
# 166 2024-06-15          16.99
# 112 2024-04-22          15.00
# 136 2024-05-16           6.80
# 226 2024-08-14           6.70
# 106 2024-04-16           6.50
#
# [240 rows x 2 columns]

# %% [markdown]
# * the date with highest revenue is displayed in order

# %% [markdown]
# # 17. Check if there are any duplicate values in the 'Transaction ID' column.

# %%
data[data['Transaction ID'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Date, Product Category, Product Name, Units Sold, Unit Price, Total Revenue, Region, Payment Method, total revenue]
# Index: []

# %% [markdown]
# * there are no duplicates in the Transaction ID column

# %% [markdown]
# # 18. Filter the dataset to include only transactions where Quantity is greater than 3.

# %%
data[data['Units Sold']>3]
# Out:
#      Transaction ID        Date Product Category  \
# 3             10004  2024-01-04            Books
# 5             10006  2024-01-06           Sports
# 8             10009  2024-01-09         Clothing
# 17            10018  2024-01-18           Sports
# 32            10033  2024-02-02         Clothing
# 33            10034  2024-02-03            Books
# 38            10039  2024-02-08         Clothing
# 45            10046  2024-02-15            Books
# 47            10048  2024-02-17           Sports
# 53            10054  2024-02-23           Sports
# 54            10055  2024-02-24      Electronics
# 56            10057  2024-02-26         Clothing
# 62            10063  2024-03-03         Clothing
# 63            10064  2024-03-04            Books
# 68            10069  2024-03-09         Clothing
# 74            10075  2024-03-15         Clothing
# 75            10076  2024-03-16            Books
# 83            10084  2024-03-24           Sports
# ...

# %% [markdown]
# # 19. Calculate the total revenue for each CustomerID.

# %%
data[['Transaction ID','Total Revenue']]
# Out:
#      Transaction ID  Total Revenue
# 0             10001        1999.98
# 1             10002         499.99
# 2             10003         209.97
# 3             10004          63.96
# 4             10005          89.99
# ..              ...            ...
# 235           10236         159.99
# 236           10237         270.00
# 237           10238          32.97
# 238           10239          55.00
# 239           10240          59.98
#
# [240 rows x 2 columns]

# %% [markdown]
# # 20. Group the data by 'InvoiceNo' and find the maximum 'UnitPrice' for each invoice.

# %%
data.groupby(['Transaction ID'])['Unit Price'].max().to_frame()
# Out:
#                 Unit Price
# Transaction ID
# 10001               999.99
# 10002               499.99
# 10003                69.99
# 10004                15.99
# 10005                89.99
# ...                    ...
# 10236               159.99
# 10237                90.00
# 10238                10.99
# 10239                55.00
# 10240                29.99
#
# [240 rows x 1 columns]

# %%
data.
# Out:
#      Transaction ID       Date Product Category  \
# 0             10001 2024-01-01      Electronics
# 1             10002 2024-01-02  Home Appliances
# 2             10003 2024-01-03         Clothing
# 3             10004 2024-01-04            Books
# 4             10005 2024-01-05  Beauty Products
# ..              ...        ...              ...
# 235           10236 2024-08-23  Home Appliances
# 236           10237 2024-08-24         Clothing
# 237           10238 2024-08-25            Books
# 238           10239 2024-08-26  Beauty Products
# 239           10240 2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %% [markdown]
# # Data Visualization

# %%
data['Month']=data['Date'].dt.month_name()
sns.lineplot(x=data['Month'],y=data['Total Revenue'],data=data,marker='*')
plt.title('Line Plot of Total Revenue in Months')
plt.xlabel('months')
plt.ylabel('Total revenue')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * the data shows the trends in total revenue of each month
# * the sales is the highest in january followed by april
# * decreasing trend noted with increase in time

# %%
data.groupby(['Product Name'])['Units Sold'].max().sort_values(ascending=False).head(6).plot(kind='pie',autopct='%1.1f%%');

# %% [markdown]
# * the top 6 products sold are plotted
# * Hanes ComfortSoft Tshirt the first with 25.6% and Forever 21 Graphic Tee the second and rest five sharing same 15.4%

# %%
Which product categories generate the highest revenue?

# %%
sns.barplot(x=data['Product Category'],y=data['Total Revenue'],data=data)
plt.title('Product categories with the highest revenue')
plt.xlabel('Product Category')
plt.ylabel('Total revenue')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * Electronics Category generate more revenue when compared all other categories
# * Books Category fall on the 6th position

# %%
data.groupby(['Region','Product Category'])['Total Revenue'].sum().sort_values(ascending=False).plot(kind='barh');
plt.title('Regions and highest revenue producing categories')
plt.xlabel('Total revenue')
plt.show()

# %% [markdown]
# * north america has the highest sales in electronics at the same time least sales in Books
# * whereas Home appliances and Beauty Products are more profitable in Europe
# * Asia has shown profitable in Clothing and Sports

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Month', y='Total Revenue', data=data)
plt.title('Box Plot of Total Revenue by Region')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45) 
plt.show()

# %% [markdown]
# * the presence of outliers in several months suggests that there might be some months with exceptionally high or low revenue compared to general trend

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Region', y='Total Revenue', data=data)
plt.title('Violin Plot of Total Revenue by Region')
plt.xlabel('Region')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)  
plt.show()

# %% [markdown]
# * the plot for Europe suggests a wider range of revenue compared to other two regions
# * Asia seems to have a slightly light higher median revenue compared to North America and Europe
# * the revenue distribution in North America appears relatively concentrated around the median

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Product Category', y='Units Sold', data=data)
plt.title('Line Plot of Units Sold by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Units Sold')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * Units sold in Clothing category is the highest followed by books and the sports
# * the beauty products are the least sold
# * Electronics and Home appliances has almost similar amount of units sold

# %%
data['Payment Method'].value_counts().plot(kind='bar');
plt.title('Distribution of Payment Methods')
plt.xlabel('Payment Methods')
plt.show()

# %% [markdown]
# * the more frequent transactions are done with credit cards followed by debit card purchases
# * purchases done with Debit cards are the least

# %%
data.groupby(['Product Name'])['Total Revenue'].max().sort_values(ascending=False).head(9).plot(kind='line')
plt.title('Top revenue producing products')
plt.xlabel('Product Name')
plt.ylabel('Total Revenue')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * the top 9 revenue generating items are plotted
# * Canon EOS R5 Camera is the one generating highest revenue with Samsung Odyssey G9 Gaming Monitor at the 9th position

# %%
data.groupby(['Product Category'])['Units Sold'].sum().plot(kind='bar');
plt.title('Product categories and their units sold')
plt.xlabel('Product Category')
plt.ylabel('Units Sold')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * Units sold in Clothing category is the highest followed by books and the sports
# * the beauty products are the least sold
# * Electronics and Home appliances has almost similar amount of units sold

# %%
sns.lineplot(x='Payment Method',y='Total Revenue', data=data, marker='o')
plt.title("Payment method and Product cost");

# %% [markdown]
# * the purchases with high revenue are mostly done with Credit card
# * the purchases with less cost are done with debit cards

# %%
sns.lineplot(x='Region',y='Month',data=data);

# %%
data['Day']=data['Date'].dt.day_name()

# %%
sns.lineplot(x='Day',y='Total Revenue', data=data);
plt.title('Revenue Generation in each days')
plt.xlabel('Days')
plt.ylabel('Total revenue')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * the plot shows the trend of Sales on each days of the week
# * Friday is shown to have highest sales against wednesday and thursday with the least

# %%
sns.scatterplot(x='Day',y='Units Sold', data=data);
plt.title('Units sold in each days')
plt.xlabel('Days')
plt.ylabel('Units Sold')
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# * the units sold in each days are plotted in the above graph
# * the units are sold in large amounts on sundays with all other days maintaining similar trend of sales

# %%
sns.barplot(x='Region',y='Units Sold', data=data);
plt.title('Units sold in different regions')
plt.xlabel('Regions')
plt.ylabel('Units Sold')
plt.show()

# %% [markdown]
# * Asia has the highest range of Units Sold followed by North America and Europe the least in comparison

# %%
data.groupby(['Month','Product Category'])['Total Revenue'].sum().sort_values(ascending=False).head().plot(kind='pie',autopct='%1.1f%%');
plt.title('Highest revenue producing categories and monthly trends')
# Out:
# Text(0.5, 1.0, 'Highest revenue producing categories and monthly trends')

# %% [markdown]
# * electronics has generated highest revennue in the month of January and April with 28.1% and 23.6% respectively
# * though highest revenue in march is generated from Home appliances, Electronics has again scored in May

# %%
sns.lineplot(x='Region',y='Payment Method',data=data);
plt.title('Trends in Payment method across regions')
plt.xlabel('Region')
plt.ylabel('Payment method')
plt.show()

# %% [markdown]
# * the purchases done in North America are mostly by Credit cards
# * whereas paypal has maintained stable transaction mode in europe and asia

# %%
sns.barplot(y='Payment Method',x='Month',data=data)
plt.title('Trends in Payment Method')
plt.xlabel('Months')
plt.ylabel('Payment Methods')
plt.show()

# %%
data.groupby('Month')['Total Revenue'].mean().plot(kind='pie',autopct='%1.1f%%')
plt.title('Total revenue across months');

# %% [markdown]
# * January has been plotted for highest revenue generation with 17.5%
# * March stands with 15.5% of total generation
# * the revenue generated is comparitively lesser in july

# %%
data.groupby(['Product Name','Payment Method'])['Total Revenue'].max().sort_values(ascending=False).head().plot(kind='pie',autopct='%1.1f%%');
plt.title('Top 5 revenue generating products and their transaction methods')
# Out:
# Text(0.5, 1.0, 'Top 5 revenue generating products and their transaction methods')

# %% [markdown]
# * the most revenue generated product is  canon EOS R5 Camera which is purchased with Credit card
# * LG OLED TV with second most revenue generation is carried out by paypal transaction
# * the MacBook pro 16 inch, Apple MacBook pro 16 inch and iPhone 14 Pro is purchased via Credit cards
